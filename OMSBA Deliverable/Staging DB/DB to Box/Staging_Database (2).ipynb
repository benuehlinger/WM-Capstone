# %%
# !pip install mysql-connector-python
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: mysql-connector-python in /usr/local/lib/python3.10/dist-packages (9.1.0)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # db.py

# %%
import mysql.connector as mysql

# Connect to the Amazon RDS MySQL database and set the default schema to 'cms'
db = mysql.connect(
    host='wm-capstone-db.cviy020ogwh2.us-east-2.rds.amazonaws.com',  # RDS endpoint
    user='benuehlinger',  # Master username
    password='WMCapstone1!',  # Master password
    database='cms',  # Default schema set to 'cms'
    port=3306  # MySQL port
)

# Set autocommit to True for immediate data changes
db.autocommit = True

# Create cursor objects for executing SQL queries
cur = db.cursor(buffered=False)
curp = db.cursor(prepared=True)

# # Ensure the 'cms' schema exists (create it if not already present)
# cur.execute("CREATE SCHEMA IF NOT EXISTS cms;")
# cur.execute("USE cms;")  # Switch to the 'cms' schema explicitly

# Test the connection
try:
    print("Connected to the 'cms' schema successfully!")
except mysql.Error as e:
    print(f"Error: {e}")
# Out:
# Connected to the 'cms' schema successfully!

# %% [markdown]
# # I needed, drop all tables loaded (temp%, cms_tables, load_log)

# %%
# Step 1: Query to find tables that match the criteria
cur.execute("""
    SELECT GROUP_CONCAT(table_name)
    FROM information_schema.tables
    WHERE table_schema = 'cms'
    AND (table_name LIKE 'temp%' OR table_name IN ('cms_tables', 'load_log'));
""")

# Step 2: Fetch the result to handle cases where no tables are found
result = cur.fetchone()
if result[0] is None:  # No tables match the criteria
    print("No tables to drop.")
else:
    tables = result[0]  # Tables to drop as a comma-separated list

    # Step 3: Prepare and execute the DROP TABLE query dynamically
    drop_query = f"DROP TABLE IF EXISTS {tables};"
    cur.execute(drop_query)
    print(f"Dropped tables: {tables}")

# %% [markdown]
# Name directory for which folders of past data exist

# %% [markdown]
# # Create necessary folder directory if doesnt exist

# %%
import os

# Path to the DataDir folder where folders will be created
dataDirs = '/content/drive/My Drive/Capstone Project/Staging Database/DataDir'

# List of folder names to create based on your data time periods
# folders = [
#     "24Oct", "24Jul", "24Apr", "24Jan",
#     "23Nov", "23Oct", "23Jul", "23Apr", "23Jan",
#     "22Oct", "22Jul", "22Apr", "22Jan",
#     "21Oct", "21Jul", "21Apr", "21Mar", "21Jan",
#     "20Oct", "20Jul", "20Apr", "20Jan",
#     "19Oct", "19Jul", "19Apr", "19Mar",
#     "18Oct", "18Jul", "18May", "18Jan",
#     "17Oct", "17Jul", "17Apr"
# ]

# # Create folders in DataDir
# for folder in folders:
#     folder_path = os.path.join(DataDir, folder)
#     try:
#         os.makedirs(folder_path, exist_ok=True)  # Create folder if it doesn't exist
#         print(f"Created folder: {folder_path}")
#     except Exception as e:
#         print(f"Error creating folder {folder_path}: {e}")

# %% [markdown]
# # load_all

# %%
import os  # For path operations
import glob  # For file searching
import re  # For regex operations
import csv  # For reading CSV files

# Ensure load_log table exists
try:
    cur.execute("""
        CREATE TABLE IF NOT EXISTS load_log (
            tempName VARCHAR(255),
            fileName VARCHAR(255),
            origName VARCHAR(255),
            tblStatus VARCHAR(50),
            errMessage TEXT,
            loadTimestamp TIMESTAMP DEFAULT CURRENT_TIMESTAMP
        )
    """)
    print("Table `load_log` ensured to exist.")
except Exception as e:
    print(f"Error ensuring `load_log` exists: {e}")

# Path to the directory containing your files
Home = '/content/drive/My Drive/Capstone Project/Staging Database'
DataDir = os.path.join(Home, 'DataDir')  # Path to the DataDir folder

# Useful CSVs found in LOAD.TXT
load_txt_path = os.path.join(Home, 'LOAD.txt')
with open(load_txt_path, 'r') as f:
    CSV = [l.rstrip().lower() for l in f.readlines()]  # Filter list from LOAD.txt

# Load CSVs into MySQL tables
dataDirs = [os.path.join(DataDir, folder) for folder in os.listdir(DataDir) if os.path.isdir(os.path.join(DataDir, folder))]
tblCount = 0  # Initialize the table counter

for folder in dataDirs:
    print(f"** Processing folder: {folder} **")

    csv_files = glob.glob(f'{folder}/*.csv')  # Find all CSV files in the current folder
    for fname in csv_files:
        m = re.search('(.+?)\\.csv', os.path.basename(fname))  # Extract base name of the CSV file
        nm = m.groups()[0]

        # Filter based on LOAD.TXT
        if nm.lower() not in CSV:
            print(f"Skipping {fname}, not listed in LOAD.txt.")
            continue

        print(f"Processing {fname}")
        f = open(fname, 'r')
        csvfile = csv.DictReader(f)
        try:
            tblCount += 1
            try:
                cur.execute(f'DROP TABLE IF EXISTS `{nm}`')  # Drop table if it exists
            except Exception as drop_err:
                print(f"Warning: Unable to drop table `{nm}`. Continuing...")

            tblnm = f"temp{tblCount}"  # Temporary table name
            q = f'CREATE TABLE `{tblnm}` ('
            q += ','.join(f'`{col}` VARCHAR(255)' for col in csvfile.fieldnames)  # Create columns based on CSV headers
            q += ')'
            cur.execute(q)
            cur.execute(f'ALTER TABLE `{tblnm}` ADD CMS_Data_ID VARCHAR(20)')
            cur.execute(
                "INSERT INTO load_log (tempName, fileName, origName, tblStatus, errMessage) VALUES (%s, %s, %s, %s, NULL)",
                (tblnm, fname, nm, 'empty')
            )
        except Exception as err:
            print(f"\tERR: Could not create {tblnm} .. skipping")
            print(f"\t{str(err)}")
            cur.execute(
                "INSERT INTO load_log (tempName, fileName, origName, tblStatus, errMessage) VALUES (%s, %s, %s, NULL, %s)",
                (tblnm, fname, nm, str(err))
            )
            continue

        rows = [row for row in csvfile]
        f.close()
        for r in rows:
            r['CMS_Data_ID'] = folder  # Add folder metadata
        rows = [rows[i:(i + 5000)] for i in range(0, len(rows), 5000)]  # Split into batches of 5000

        try:
            print("\t", end='')
            for batch in rows:
                q = f'INSERT INTO `{tblnm}` VALUES '
                q += ','.join([str(tuple(i.values())) for i in batch])  # Insert rows
                cur.execute(q)
                print(".", end='')
            print("")

            cur.execute(f"UPDATE load_log SET tblStatus='loaded' WHERE tempName='{tblnm}'")
        except Exception as err:
            cur.execute(
                "UPDATE load_log SET errMessage=%s WHERE tempName=%s", (str(err), tblnm)
            )

db.close()

# ** run rename_tables.sql
#   Fuzzy match table names
#   Merge same tables
#   Rename to sane tables
# Out:
# Table `load_log` ensured to exist.
# ** Processing folder: /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct **
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Timely and Effective Care - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Structural Measures - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/HCAHPS - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/HCAHPS - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Healthcare Associated Infections - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Healthcare Associated Infections - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/FY2015_Value_Based_Incentive_Payment_Amount.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Hospital Returns - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/FY2015_Percent_Change_in_Medicare_Payments.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Ambulatory Surgical Measures-State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Complications and Deaths - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Ambulatory Surgical Measures-National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/VHA provider level data.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/FY2015_Distribution_of_Net_Change_in_Base_Op_DRG_Payment_Amt.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/VHA measure dates.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/FY2015_Net_Change_in_Base_Op_DRG_Payment_Amt.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Footnote Crosswalk.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/FINAL CJR Quality PR - PY1 File Values_October.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HCAHPS_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/HBIPS_Oct2017_19SEP.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/HOSPITAL_ANNUAL_QUALITYMEASURE_PCH_EBRT_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Complications and Deaths - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Value of Care - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Hospital Returns - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Ambulatory Surgical Measures-Facility.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Timely and Effective Care - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Payment - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Payment - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/READMISSION REDUCTION.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/TimelyandEffectiveCare_Oct2017_25SEP17.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Timely and Effective Care - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/VA_IPSHEP_Oct2017CMS_19SEP17.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/VA_PSI_Oct2017_07SEP17.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Payment and Value of Care - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Readmissions and Deaths - VA.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Outpatient Imaging Efficiency - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Outpatient Imaging Efficiency - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Medicare Hospital Spending per Patient - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Outpatient Procedures - Volume.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Medicare Hospital Spending per Patient - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Complications and Deaths - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/hvbp_tps_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Measure Dates.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/hvbp_imm2_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HCAHPS_STATE.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/HOSPITAL_QUARTERLY_HAC_DOMAIN_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/HOSPITAL_QUARTERLY_IPFQR_MEASURES_STATE.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/HOSPITAL_QUARTERLY_IPFQR_MEASURES_NATIONAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HCAHPS_NATIONAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/HOSPITAL_QUARTERLY_MSPB_6_DECIMALS.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/hvbp_efficiency_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/hvbp_pc_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/hvbp_ami_11_14_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_OCM_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Healthcare Associated Infections - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Hospital General Information.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Hospital Returns - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/HCAHPS - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/hvbp_safety_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Outpatient Imaging Efficiency - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/hvbp_hcahps_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Medicare Hospital Spending per Patient - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/hvbp_clinical_care_outcomes_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/HOSPITAL_QUARTERLY_IPFQR_MEASURES_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/Medicare Hospital Spending by Claim.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Oct/HOSPITAL_QUARTERLY_AHRQ_PSI_90_6decimals.csv, not listed in LOAD.txt.
# ** Processing folder: /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct **
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/VA_IPF_08_06_2018.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/HCAHPS - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/FY2016_Net_Change_in_Base_Op_DRG_Payment_Amt.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/FY2016_Distribution_of_Net_Change_in_Base_Op_DRG_Payment_ Amt.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/footnotes_deliver_17q2_18q1.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/FY2016_Percent_Change_in_Medicare_Payments.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Veterans_Health_Administration_Provider_Level_Data.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Unplanned Hospital Visits - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Veterans_Health_Administration_Measure_Dates.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Timely and Effective Care - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Timely and Effective Care - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/asc_national_pr17q2_18q1.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/ASC_National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/CJR PY2 Quality Reporting_October 2018_Production File.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Healthcare Associated Infections - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/DoD_TE_October 2018 Production 08_30_18.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/DoD_TRISS_Final File Oct 2018.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/asc_CCN_pr17q2_18q1.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Complications and Deaths - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/asc_state_pr17q2_18q1.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Complications and Deaths - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/ASC_State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Value of Care - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Unplanned Hospital Visits - State.csv, not listed in LOAD.txt.
# Processing /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/VA_TE.csv
# 	ERR: Could not create temp1 .. skipping
# 	1050 (42S01): Table 'temp1' already exists
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Timely and Effective Care - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/VA_PSI.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Outpatient Procedures - Volume.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Readmissions and Deaths - VA_07_10_2018.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Readmissions and Deaths - COPD - VA.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Measure Dates October 2018.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Medicare Hospital Spending per Patient - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Payment - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Medicare Hospital Spending per Patient - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Payment - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Outpatient Imaging Efficiency - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Outpatient Imaging Efficiency - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/ASC_Facility.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Unplanned Hospital Visits - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Complications and Deaths - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HCAHPS_STATE.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/hvbp_clinical_care_11_07_2017.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HCAHPS_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/hopd_national_pr17q2_18q1.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/hopd_state_pr17q2_18q1.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/HOSPITAL_ANNUAL_QUALITYMEASURE_PCH_EBRT_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/HOSPITAL_QUARTERLY_MSPB_6_DECIMALS.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/HOSPITAL_QUARTERLY_HAC_DOMAIN_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/IPFQR_FUH_QualityMeasures_National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/IPFQR_QualityMeasures_State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/hvbp_efficiency_11_07_2017.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Labels - Measures for Public Reporting OAS CAHPS-October 2018.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/IPFQR_FUH_QualityMeasures_Facility.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/IPFQR_FUH_QualityMeasures_State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/hvbp_tps_11_07_2017.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/HCAHPS - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/hopd_CCN_pr17q2_18q1.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Healthcare Associated Infections - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/FY2016_Value_Based_Incentive_Payment_Amount.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Footnote Crosswalk.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HCAHPS_NATIONAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/HOSPITAL_ANNUAL_QUALITYMEASURE_PCH_OCM_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/IPFQR_QualityMeasures_National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Medicare Hospital Spending per Patient - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/IPFQR_QualityMeasures_Facility.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Outpatient Imaging Efficiency - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Medicare Hospital Spending by Claim.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/hvbp_safety_11_07_2017.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/hvbp_hcahps_11_07_2017.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Healthcare Associated Infections - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Hospital General Information.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/HCAHPS - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Structural Measures - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Readmission Reduction.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/18Oct/Payment and Value of Care - Hospital.csv, not listed in LOAD.txt.
# ** Processing folder: /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct **
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/ASC_CCN_pr18q2_19q1.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/ASC_State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/ASC_National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/ASC_NATIONAL_pr18q2_19q1.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/ASC_STATE_pr18q2_19q1.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/CEBP_IQR_10_17_2018.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/FY2017_Value_Based_Incentive_Payment_Amount_2018-11-30.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/ASC_Facility.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/FY2017_Percent_Change_in_Medicare_Payments_2018-12-03.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/CEBP_IQR_6_decimals_10_17_2018.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/hvbp_tps_11_09_2018.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/HOPD_CCN_pr18q2_19q1.csv, not listed in LOAD.txt.
# Processing /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/VA_TE.csv
# 	.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Unplanned Hospital Visits - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/VA_IPF.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Unplanned Hospital Visits - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Data_Updates_October_2019_updated.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Outpatient Imaging Efficiency - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Medicare Hospital Spending Per Patient - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Outpatient Imaging Efficiency - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Medicare Hospital Spending Per Patient - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Healthcare Associated Infections - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Veterans_Health_Administration_Measure_Dates.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Readmissions and Deaths - COPD - VA.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Healthcare Associated Infections - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/HCAHPS - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Timely and Effective Care - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Payment - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/HCAHPS - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Timely and Effective Care - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Payment - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Medicare Hospital Spending Per Patient - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Measure_Dates.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/IPFQR_QualityMeasures_National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/IPFQR_QualityMeasures_State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Veterans_Health_Administration_Provider_Level_Data.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Value of Care - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Outpatient Procedures - Volume.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/VA_PSI.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/HOPD_STATE_pr18q2_19q1.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/HOSPITAL_ANNUAL_QUALITYMEASURE_PCH_EBRT_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HAI_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/HOSPITAL_ANNUAL_QUALITYMEASURE_PCH_OCM_Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HCAHPS_NATIONAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/HOPD_NATIONAL_pr18q2_19q1.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/HOSPITAL_QUARTERLY_HAC_DOMAIN_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/CJR PY3 Quality Reporting_July 2019_Production File.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/DoD_TE_October 2019 Production.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/CEBP_IQR_state_10_17_2018.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/CEBP_IQR_national_10_17_2018.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HCAHPS_STATE.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/hvbp_efficiency_11_09_2018.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/HOSPITAL_QUARTERLY_MSPB_6_DECIMALS.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HCAHPS_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Complications and Deaths - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/DoD_TRISS_Final File October 2019.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Complications and Deaths - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/FY2017_Net_Change_in_Base_Op_DRG_Payment_Amt_2018-11-30.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/footnotes_deliver_18q2_19q1.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/FY2017_Distribution_of_Net_Change_in_Base_Op_DRG_Payment_Amt_2018-11-30.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Footnote Crosswalk.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/hvbp_hcahps_11_09_2018.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/IPFQR_QualityMeasures_Facility.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Medicare Hospital Spending by Claim.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/hvbp_safety_11_09_2018.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Unplanned Hospital Visits - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Timely and Effective Care - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Structural Measures - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Payment and Value of Care - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Outpatient Imaging Efficiency - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/HCAHPS - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Healthcare Associated Infections - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/HOSPITAL_QUARTERLY_QUALITYMEASURE_RRP_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/hvbp_clinical_care_11_09_2018.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Hospital General Information.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/CEBP_IQR_Breakdowns_by_Claim_Type_10_17_2018.csv, not listed in LOAD.txt.
# Processing /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/CMS_PSI_6_decimal_file.csv
# 	...........
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/19Oct/Complications and Deaths - Hospital.csv, not listed in LOAD.txt.
# ** Processing folder: /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct **
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/4jcv-atw7.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/4j6d-yzce.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/4gkm-5ypv.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/4aav-bsmy.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/5gv4-jwyv.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/3n5g-6b7f.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/tf3h-mrrs.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/su9h-3pvj.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/s5xg-sys6.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/s5pj-hua3.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/rs6n-9qwg.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/yq43-i98g.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/z8ax-x9j1.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/p7bc-fjpi.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/48nr-hqxx.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/pudb-wetr.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/yd3s-jyhd.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/xrgf-x36b.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/x663-bwbj.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/y9us-9xdf.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/6qxe-iqz8.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/ypbt-wvdk.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/6pfg-whmx.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/yizn-abxn.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/5hk7-b79m.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/ptds-r8im.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/uyx4-5s7f.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/u625-zae7.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/vtqa-m4zn.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/wue8-3vwe.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/tqkv-mgxq.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/pdc_s3_hos_data_su86_ag6b.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/rrqw-56er.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/qqw3-t4ie.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/qatj-nmws.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/k653-4ka8.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/98ix-2iqy.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/k2ze-bqvw.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/esr2-9zyn.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/if5v-4x48.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/dc76-gh7x.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/isrn-hqyy.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/iy27-wz37.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/gbq5-7hzr.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/di9i-zzrc.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/e6hj-umam.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/g3fg-3myg.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/jfnd-nl7s.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/bzsr-4my4.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/9g7e-btyt.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/akfs-5dgr.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/cvcs-xecj.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/ygty-mm5a.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/axe7-s95e.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/bs2r-24vh.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/apyc-v239.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/99ue-w85f.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/84jm-wiui.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/q9vs-r7wp.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/yv7e-xc69.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/wkfw-kthe.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/xubh-q36u.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/ynj2-r877.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/4hje-vua3.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/632h-zaca.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/nrth-mfg3.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/77hc-ibv8.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/9n3s-kdb3.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/muwa-iene.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/dgmq-aat3.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/dgck-syfz.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/avtz-f2ge.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/20Oct/c7us-v4mf.csv, not listed in LOAD.txt.
# ** Processing folder: /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct **
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/Data_Updates_October_2021.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/IPFQR_QualityMeasures_State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/pdc_s3_hos_data_su86_ag6b.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/Healthcare_Associated_Infections-State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/CJR_PY5_Quality_Reporting_July_2021_Production_File.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/VA_IPF.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/Unplanned_Hospital_Visits-State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/Payment-State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/ASCQR_OAS_CAHPS_STATE.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/ASC_National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/PCH_HCAHPS_NATIONAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/Footnote_Crosswalk.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/Outpatient_Imaging_Efficiency-National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/PCH_HCAHPS_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/OAS_CAHPS_Footnotes.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/Outpatient_Imaging_Efficiency-State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/Timely_and_Effective_Care-State.csv, not listed in LOAD.txt.
# Processing /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/VA_TE.csv
# 	.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/FY2019_Distribution_of_Net_Change_in_Base_Op_DRG_Payment_Amt.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/PCH_ONCOLOGY_CARE_MEASURES_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/FY2019_Value_Based_Incentive_Payment_Amount.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/FY2019_Percent_Change_in_Medicare_Payments.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/OQR_OAS_CAHPS_STATE.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/Healthcare_Associated_Infections-National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/ASCQR_OAS_CAHPS_NATIONAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/Veterans_Health_Administration_Provider_Level_Data.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/PCH_HEALTHCARE_ASSOCIATED_INFECTIONS_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/FY_2021_HAC_Reduction_Program_Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/Payment-National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/PCH_OUTCOMES_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/OQR_OAS_CAHPS_BY_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/PCH_EXTERNAL_BEAM_RADIOTHERAPY_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/PCH_HCAHPS_STATE.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/OQR_OAS_CAHPS_NATIONAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/IPFQR_QualityMeasures_National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/Medicare_Hospital_Spending_Per_Patient-State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/Medicare_Hospital_Spending_Per_Patient-Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/Complications_and_Deaths-National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/hvbp_efficiency_and_cost_reduction.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/hvbp_tps.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/Medicare_Hospital_Spending_Per_Patient-National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/HCAHPS-State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/HOSPITAL_QUARTERLY_MSPB_6_DECIMALS.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/Timely_and_Effective_Care-National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/Unplanned_Hospital_Visits-National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/ASCQR_OAS_CAHPS_BY_ASC.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/PCH_OUTCOMES_NATIONAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/21Oct/Value_of_Care-National.csv, not listed in LOAD.txt.
# ...
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/Complications and Deaths - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/VA_IPSHEP_Jul2017CMS_08MAY17.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HCAHPS_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_OCM_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/hvbp_ami_11_14_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HCAHPS_NATIONAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HCAHPS_STATE.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/Measure Dates.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/Complications and Deaths - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/MORT_READM_July2017.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/hvbp_tps_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/hvbp_pc_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/hvbp_imm2_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/hvbp_efficiency_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/Outpatient Imaging Efficiency - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/Outpatient Imaging Efficiency - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/Medicare Hospital Spending per Patient - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/HOSPITAL_QUARTERLY_MSPB_6_DECIMALS.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/HOSPITAL_QUARTERLY_HAC_DOMAIN_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/HOSPITAL_QUARTERLY_IPFQR_MEASURES_STATE.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/Outpatient Procedures - Volume.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/Medicare Hospital Spending per Patient - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/HCAHPS - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/Outpatient Imaging Efficiency - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/Medicare Hospital Spending per Patient - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/hvbp_safety_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/Medicare Hospital Spending by Claim.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/hvbp_clinical_care_outcomes_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/hvbp_hcahps_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/Hospital General Information.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/HOSPITAL_QUARTERLY_IPFQR_MEASURES_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/Hospital Returns - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Jul/Healthcare Associated Infections - Hospital.csv, not listed in LOAD.txt.
# ** Processing folder: /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr **
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/PSI_April2017.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Readmissions and Deaths - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/corrected_hai_clabsi_April2017_2015Q3-2016Q2_state.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/corrected_hai_clabsi_April2017_2015Q3-2016Q2_fac.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/corrected_hai_cauti_April2017_2015Q3-2016Q2_natl.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/corrected_hai_cdiff_2016Q3_fac_04_19_2017.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/VA_IPSHEP_Apr2017CMS_09MAR17.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/corrected_hai_cauti_April2017_2015Q3-2016Q2_state.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Ambulatory Surgical Measures-State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Value of Care - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Complications - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Ambulatory Surgical Measures-National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Complications - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/corrected_hai_cauti_April2017_2015Q3-2016Q2_fac.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/READMISSION REDUCTION.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/VA_HBIPS_December2016_CMS_Submission.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Timely and Effective Care - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Readmissions and Deaths - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/PR_IPF_FluVac_2016Q1_state_03_15_2017-Corrected.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Readmissions and Deaths - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Payment - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Timely and Effective Care - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/PR_IPF_FluVac_2016Q1_natl_03_15_2017-Corrected.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Payment and Value of Care - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HCAHPS_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Healthcare Associated Infections - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Medicare Hospital Spending per Patient - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Outpatient Imaging Efficiency - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Outpatient Procedures - Volume.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Medicare Hospital Spending per Patient - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Payment - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Measure Dates.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/hvbp_tps_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Outpatient Imaging Efficiency - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Complications - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/hvbp_pc_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/hvbp_efficiency_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Ambulatory Surgical Measures-Facility.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/corrected_hai_clabsi_April2017_2015Q3-2016Q2_natl.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/corrected_hai_cdiff_2016Q3_natl_04_19_2017.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/HOSPITAL_QUARTERLY_IPFQR_MEASURES_STATE.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Footnote Crosswalk.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/FY2015_Percent_Change_in_Medicare_Payments.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/FY2015_Distribution_of_Net_Change_in_Base_Op_DRG_Payment_Amt.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/FY2015_Net_Change_in_Base_Op_DRG_Payment_Amt.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/corrected_hai_cdiff_2016Q3_state_04_19_2017.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/FY2015_Value_Based_Incentive_Payment_Amount.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/HOSPITAL_QUARTERLY_MSPB_6_DECIMALS.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/GLOBAL_April2017_09March2017.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/hvbp_imm2_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_OCM_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HCAHPS_NATIONAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/HOSPITAL_QUARTERLY_QUALITYMEASURE_PCH_HCAHPS_STATE.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/hvbp_ami_11_14_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/HAI_FluVac_2016Q1_state_03_17_2017-Corrected.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/HAI_FluVac_2016Q1_natl_03_17_2017-Corrected.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/HOSPITAL_QUARTERLY_HAC_DOMAIN_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/HCAHPS - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/HCAHPS - National.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/MORT_READM_April2017.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Timely and Effective Care - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Healthcare Associated Infections - State.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/HOSPITAL_QUARTERLY_IPFQR_MEASURES_NATIONAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Structural Measures - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/hvbp_clinical_care_outcomes_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Medicare Hospital Spending per Patient - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/hvbp_hcahps_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/HOSPITAL_QUARTERLY_IPFQR_MEASURES_HOSPITAL.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/hvbp_safety_11_10_2016.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Medicare Hospital Spending by Claim.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Hospital General Information.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Healthcare Associated Infections - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/HCAHPS - Hospital.csv, not listed in LOAD.txt.
# Skipping /content/drive/My Drive/Capstone Project/Staging Database/DataDir/17Apr/Outpatient Imaging Efficiency - Hospital.csv, not listed in LOAD.txt.

# %% [markdown]
# # Match Tables

# %%
# -*- coding: utf-8 -*-
"""
Try to fuzzy match tables
    - Find candidates
    - Check structure
    - Merge
    - Rename

"""

# from db import *

#with open('load.txt','r') as f:
#    CSV = [l.rstrip().lower() for l in f.readlines()]

# Drop unneeded tables. Heuristic.
q = """select tempName
	from load_log
 where
	NOT (fileName like '%hospital%'
    or fileName like '%decimal%'
    or fileName like '%va_te%'
    or fileName like '%hvbp%')
    or fileName like '%state%'
    or fileName like '%national%'
    or filename like '%quarterly%'
    or filename like '%quality%'
    or filename like 'PCH%'
    or filename like '%reduction%'
    or filename like '%readmission%'
    or filename like '%spending%'
    or filename like '%payment%'
    or filename like '%measure%'
    """
cur.execute(q)
altersql = [f"alter table cms.`{row[0]}` rename cms_unused.`{row[0]}`" for row in cur.fetchall()]
for q in altersql:
    try:
        cur.execute(q)
    except:
        pass
db.commit()

try:
    cur.execute('drop table cms_unused.load_log')
    q = """create table cms_unused.load_log as
    select * from load_log
    where tempName in (
    select table_name from information_Schema.tables
    	where table_schema = 'cms_unused')"""
    cur.execute(q)
except:
    pass

# Remove deleted tables from log
q = """delete from load_log
  where not exists (select 'x' from information_schema.tables where table_schema = 'cms' and table_name = tempName);"""
cur.execute(q)
db.commit()

# Fuzzy Match tables using levenshtein
cur.execute('call cms.match_tables')




# # cur.execute('select tblName from cms_tables')
# # CSV = [row[0] for row in cur.fetchall()]

# # cur.execute('select tempName,fileName from load_log')
# # cur.fetchall()

# fig,(ax1,ax2) = plt.subplots(2,dpi=120)

# fig.tight_layout(pad=3)
# ax1.hist(df2['Score'],bins=30)
# ax1.set_title('CABG Mortality CMSApr21 Data')
# ax1.axvline(x=5.4,color='k',ls=':')
# ax1.set_xlabel('Score')
# ax1.set_ylabel('Number of Facilities')
# #plt.text()

# ax2.hist(df2['den'],bins=30)
# ax2.set_title('CABG Volumes CMSApr21 Data')
# ax2.axvline(x=134,color='k',ls=':')
# ax2.set_xlabel('CABG Volume')
# ax2.set_ylabel('Number of Facilities')
# #plt.text()

# plt.scatter(df2['den'],df2['Score'],s=3)
# plt.title('CABG Volume vs CABG Mortality Score')
