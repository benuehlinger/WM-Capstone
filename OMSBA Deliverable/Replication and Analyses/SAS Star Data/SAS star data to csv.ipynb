# %%
# !pip install pyreadstat
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 13.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

import pyreadstat

# Path to the SAS file in Google Drive
file_path = '/content/drive/My Drive/Capstone Project/SAS Star Data/alldata_2024jul.sas7bdat'

# Read the file into a DataFrame
df, meta = pyreadstat.read_sas7bdat(file_path)

# Display the first few rows of the data
df.head()


# # Path to save the CSV file
# output_path = '/content/drive/My Drive/Capstone Project/SAS Star Data/Alldata_2024Jul.csv'

# Save the DataFrame to a CSV file
#df.to_csv(output_path, index=False)


# df.shape

# # Get column names
# column_names = df.columns.tolist()
# print(column_names)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#   PROVIDER_ID  HAI_1_DEN_VOL  HAI_2_DEN_VOL  HAI_3_DEN_VOL  HAI_4_DEN_VOL  \
# 0      010001         9149.0        17310.0          214.0            NaN
# 1      010005         3194.0         8277.0           96.0            NaN
# 2      010006         5343.0         8715.0          111.0            NaN
# 3      010007            NaN            NaN            NaN            NaN
# 4      010008            NaN            NaN            NaN            NaN
#
#    HAI_5_DEN_VOL  HAI_6_DEN_VOL  HAI_1_DEN_PRED  HAI_2_DEN_PRED  \
# 0       104733.0       104733.0           9.597          24.766
# 1        36794.0        34887.0           1.989           4.019
# 2        63727.0        60304.0           5.801          11.166
# 3            NaN         5511.0             NaN             NaN
# 4            NaN            NaN             NaN             NaN
#
# ...

# %%
from google.colab import drive
import pyreadstat

# Mount Google Drive
# drive.mount('/content/drive')

# Path to the SAS file in Google Drive
file_path = '/content/drive/My Drive/Capstone Project/SAS Star Data/alldata_2024jul.sas7bdat'

# Read the file into a DataFrame
df, meta = pyreadstat.read_sas7bdat(file_path)

# Filter columns that start with "MORT"
mort_columns = df.filter(regex='^MORT')

# Display the first few rows of the filtered data
mort_columns.head()
# Out:
#    MORT_30_STK  MORT_30_PN  MORT_30_HF  MORT_30_COPD  MORT_30_AMI  \
# 0        0.148       0.180       0.089         0.088        0.120
# 1        0.153       0.233       0.149         0.099        0.136
# 2        0.172       0.195       0.125         0.099        0.165
# 3          NaN       0.285       0.125         0.137          NaN
# 4          NaN         NaN         NaN           NaN          NaN
#
#    MORT_30_STK_DEN  MORT_30_PN_DEN  MORT_30_HF_DEN  MORT_30_COPD_DEN  \
# 0            398.0           400.0           549.0             107.0
# 1             81.0           289.0           121.0             126.0
# 2            227.0           469.0           388.0             148.0
# 3              NaN            88.0            26.0              34.0
# 4              NaN             NaN             NaN               NaN
#
#    MORT_30_AMI_DEN  MORT_30_CABG  MORT_30_CABG_DEN
# 0            278.0         0.041             132.0
# ...
